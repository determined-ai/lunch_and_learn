# %%
import ast

# %%
results = []
with open('log_25935349.txt', 'r') as f:
  lines = f.readlines()
  for l in lines:
    results.append(ast.literal_eval(l))

# %%
print(results[0].keys())
# Out:
# dict_keys(['train_lr', 'train_class_error', 'train_loss', 'train_loss_bbox', 'train_loss_bbox_0', 'train_loss_bbox_1', 'train_loss_bbox_2', 'train_loss_bbox_3', 'train_loss_bbox_4', 'train_loss_ce', 'train_loss_ce_0', 'train_loss_ce_1', 'train_loss_ce_2', 'train_loss_ce_3', 'train_loss_ce_4', 'train_loss_giou', 'train_loss_giou_0', 'train_loss_giou_1', 'train_loss_giou_2', 'train_loss_giou_3', 'train_loss_giou_4', 'train_cardinality_error_unscaled', 'train_cardinality_error_0_unscaled', 'train_cardinality_error_1_unscaled', 'train_cardinality_error_2_unscaled', 'train_cardinality_error_3_unscaled', 'train_cardinality_error_4_unscaled', 'train_class_error_unscaled', 'train_loss_bbox_unscaled', 'train_loss_bbox_0_unscaled', 'train_loss_bbox_1_unscaled', 'train_loss_bbox_2_unscaled', 'train_loss_bbox_3_unscaled', 'train_loss_bbox_4_unscaled', 'train_loss_ce_unscaled', 'train_loss_ce_0_unscaled', 'train_loss_ce_1_unscaled', 'train_loss_ce_2_unscaled', 'train_loss_ce_3_unscaled', 'train_l
# ...

# %%
mAP = [e['test_coco_eval_bbox'][0] for e in results]

# %%
epoch_mAP = list(zip(range(len(mAP)), mAP))

# %%
epoch_mAP
# Out:
# [(0, 0.0025538420077072395),
#  (1, 0.011527500695297215),
#  (2, 0.021070423548342484),
#  (3, 0.03300545830732588),
#  (4, 0.05220723155924142),
#  (5, 0.06635717273101488),
#  (6, 0.07021201627623003),
#  (7, 0.09648345532136061),
#  (8, 0.12595051633353),
#  (9, 0.12132169576803378),
#  (10, 0.13889942327149368),
#  (11, 0.17072402325284405),
#  (12, 0.18011570626129048),
#  (13, 0.17999088703219),
#  (14, 0.189853252737455),
#  (15, 0.19842800198270916),
#  (16, 0.2097952899427293),
#  (17, 0.19861595179803312),
#  (18, 0.19998606140032524),
#  (19, 0.2161422548007891),
#  (20, 0.22186034210100375),
#  (21, 0.21804151739942518),
#  (22, 0.23180750065384612),
#  (23, 0.24115284973392673),
#  (24, 0.24746568753794493),
#  (25, 0.24309437876533527),
#  (26, 0.23789286629628004),
#  (27, 0.2565851145438387),
#  (28, 0.2661426835082726),
#  (29, 0.2531812989306306),
#  (30, 0.2610055849945535),
#  (31, 0.2663876207769244),
#  (32, 0.2560553096003799),
#  (33, 0.27252236866071594),
# ...

# %%
train_class_error = [(i, e['train_class_error'])for i, e in enumerate(results)]

# %%
train_class_error
# Out:
# [(0, 89.00132779228738),
#  (1, 79.12019087535478),
#  (2, 68.59305532154066),
#  (3, 61.27297649548683),
#  (4, 55.9626745744185),
#  (5, 51.89218590889142),
#  (6, 48.76108048591779),
#  (7, 45.82721918279474),
#  (8, 43.654311675013915),
#  (9, 42.19207899911063),
#  (10, 40.36223700087824),
#  (11, 39.215943933049324),
#  (12, 37.99025309498692),
#  (13, 36.95786587810103),
#  (14, 36.21058143010903),
#  (15, 35.608623670809195),
#  (16, 34.98714364297462),
#  (17, 34.45031236905556),
#  (18, 33.86257113109935),
#  (19, 33.509016749662756),
#  (20, 33.096595672817976),
#  (21, 32.46260029283953),
#  (22, 32.34039195327016),
#  (23, 31.8644282247597),
#  (24, 31.707364844811426),
#  (25, 31.202771773586026),
#  (26, 30.84195242764114),
#  (27, 30.57700794186943),
#  (28, 30.53587674165701),
#  (29, 30.214399341122927),
#  (30, 30.01452754147641),
#  (31, 29.73774331008201),
#  (32, 29.548786571531586),
#  (33, 29.278314962015525),
#  (34, 29.068254157062217),
# ...
